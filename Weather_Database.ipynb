# %% [markdown]
# # Challenge PART 1 Get the weather description and amount of precipitation for each city

# %%
from citipy import citipy
import numpy as np
import pandas as pd

# %%
# Create a set of random latitudes and lngitudes combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats,lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities
cities = []

# Identify nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # if the city s unique then add it to the cities list
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 601

# %%
# Import the request library
import requests

from datetime import datetime

from config import weather_api_key

# %%
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}"
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cef6761c2a8567b7e81fde3b3a6eed03

# %%
# List of city data
city_data = []
# Print to logger
print("Beginning Data Retrieval")
print("-" * 25)

# Create a counter 
record_count = 1
set_count = 1
for index, city in enumerate(cities):
    if(index % 50 == 0 and index >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city
    city_url = f'{url}&q={city.replace(" ", "+")}'
    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max tem, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        try:
            city_rain_inches = city_weather["rain"]["1h"]
        except KeyError:
            city_rain_inches = 0
        try: 
            city_snow_inches = city_weather["snow"]["1h"]
        except KeyError:
            city_snow_inches = 0
            
        # Append the city information in city_data
        city_data.append(
        {
            "City": city,
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Current Description": city_weather_description,
            "Rain (inches)": city_rain_inches,
            "Snow (inches)": city_snow_inches,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country
        })
    
    except:
        print("City not found. Skipping....")
        pass
    
# Indicate that the Data Loading is complete
print("-" * 20)
print("Data Retrieval Complete")
print("-" * 20)
# Out:
# Beginning Data Retrieval
# -------------------------
# Processing Record 1 of Set 1 | vardo
# Processing Record 2 of Set 1 | avarua
# Processing Record 3 of Set 1 | hermanus
# Processing Record 4 of Set 1 | saint-philippe
# Processing Record 5 of Set 1 | tumannyy
# City not found. Skipping....
# Processing Record 6 of Set 1 | yellowknife
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | katobu
# Processing Record 9 of Set 1 | cherskiy
# Processing Record 10 of Set 1 | qaanaaq
# Processing Record 11 of Set 1 | jalu
# Processing Record 12 of Set 1 | mahebourg
# Processing Record 13 of Set 1 | iqaluit
# Processing Record 14 of Set 1 | butaritari
# Processing Record 15 of Set 1 | hobart
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | dikson
# Processing Record 18 of Set 1 | port alfred
# Processing Record 19 of Set 1 | tessalit
# Processing Record 20 of Set 1 | hithadhoo
# Processing Record 21 of Set 1 | shenjiamen
# Processing Record 22 of Set 1 | severo-kurilsk
# Processing Record 23 of Set 1 | nanortalik
# Processing Record 24 of Set 1 | waynesboro
# Processing Record 25 of Set 1 | belushya guba
# City not found. Skipping....
# Processing Record 26 of Set 1 | lagoa
# Processing Record 27 of Set 1 | saint-francois
# Processing Record 28 of Set 1 | new norfolk
# Processing Record 29 of Set 1 | jamestown
# Processing Record 30 of Set 1 | ushuaia
# Processing Record 31 of Set 1 | aranos
# Processing Record 32 of Set 1 | saurimo
# Processing Record 33 of Set 1 | taolanaro
# City not found. Skipping....
# Processing Record 34 of Set 1 | bredasdorp
# Processing Record 35 of Set 1 | nizhneyansk
# City not found. Skipping....
# Processing Record 36 of Set 1 | provideniya
# Processing Record 37 of Set 1 | port elizabeth
# Processing Record 38 of Set 1 | jabinyanah
# Processing Record 39 of Set 1 | tasiilaq
# Processing Record 40 of Set 1 | isangel
# Processing Record 41 of Set 1 | vaini
# Processing Record 42 of Set 1 | port lincoln
# Processing Record 43 of Set 1 | manzanillo
# Processing Record 44 of Set 1 | kahului
# Processing Record 45 of Set 1 | georgetown
# Processing Record 46 of Set 1 | bonthe
# Processing Record 47 of Set 1 | grand-santi
# Processing Record 48 of Set 1 | husavik
# Processing Record 49 of Set 1 | cape town
# Processing Record 50 of Set 1 | lindas
# Processing Record 1 of Set 2 | bien hoa
# Processing Record 2 of Set 2 | carnarvon
# Processing Record 3 of Set 2 | presidente epitacio
# Processing Record 4 of Set 2 | comodoro rivadavia
# Processing Record 5 of Set 2 | necochea
# Processing Record 6 of Set 2 | sobolevo
# Processing Record 7 of Set 2 | mys shmidta
# City not found. Skipping....
# Processing Record 8 of Set 2 | mataura
# Processing Record 9 of Set 2 | namibe
# Processing Record 10 of Set 2 | atuona
# Processing Record 11 of Set 2 | saldanha
# Processing Record 12 of Set 2 | puerto ayora
# Processing Record 13 of Set 2 | turayf
# Processing Record 14 of Set 2 | shingu
# Processing Record 15 of Set 2 | nanlong
# Processing Record 16 of Set 2 | kapaa
# Processing Record 17 of Set 2 | vaitupu
# City not found. Skipping....
# Processing Record 18 of Set 2 | east london
# Processing Record 19 of Set 2 | santa cruz de tenerife
# Processing Record 20 of Set 2 | agropoli
# Processing Record 21 of Set 2 | bengkulu
# Processing Record 22 of Set 2 | kosh-agach
# Processing Record 23 of Set 2 | torbay
# Processing Record 24 of Set 2 | washington
# Processing Record 25 of Set 2 | esperance
# Processing Record 26 of Set 2 | hilo
# Processing Record 27 of Set 2 | narsaq
# Processing Record 28 of Set 2 | bluff
# Processing Record 29 of Set 2 | punta arenas
# Processing Record 30 of Set 2 | cidreira
# Processing Record 31 of Set 2 | coihaique
# Processing Record 32 of Set 2 | saint george
# Processing Record 33 of Set 2 | kruisfontein
# Processing Record 34 of Set 2 | maamba
# Processing Record 35 of Set 2 | sinnamary
# Processing Record 36 of Set 2 | aleksandrov gay
# Processing Record 37 of Set 2 | castro
# Processing Record 38 of Set 2 | albany
# Processing Record 39 of Set 2 | kamenskoye
# City not found. Skipping....
# Processing Record 40 of Set 2 | kodiak
# Processing Record 41 of Set 2 | los llanos de aridane
# Processing Record 42 of Set 2 | muros
# Processing Record 43 of Set 2 | mananara
# Processing Record 44 of Set 2 | alofi
# Processing Record 45 of Set 2 | barentsburg
# City not found. Skipping....
# Processing Record 46 of Set 2 | novyye gorki
# Processing Record 47 of Set 2 | tiksi
# Processing Record 48 of Set 2 | carman
# Processing Record 49 of Set 2 | kabarnet
# Processing Record 50 of Set 2 | clyde river
# Processing Record 1 of Set 3 | upernavik
# Processing Record 2 of Set 3 | wonthaggi
# Processing Record 3 of Set 3 | taltal
# Processing Record 4 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 5 of Set 3 | kailua
# Processing Record 6 of Set 3 | saint-pierre
# Processing Record 7 of Set 3 | haradok
# Processing Record 8 of Set 3 | tabat
# Processing Record 9 of Set 3 | haines junction
# Processing Record 10 of Set 3 | barrow
# Processing Record 11 of Set 3 | lebu
# Processing Record 12 of Set 3 | bur gabo
# City not found. Skipping....
# Processing Record 13 of Set 3 | ihlow
# Processing Record 14 of Set 3 | brainerd
# Processing Record 15 of Set 3 | flin flon
# Processing Record 16 of Set 3 | arraial do cabo
# Processing Record 17 of Set 3 | duncan
# Processing Record 18 of Set 3 | ribeira grande
# Processing Record 19 of Set 3 | dunmore town
# Processing Record 20 of Set 3 | hambantota
# Processing Record 21 of Set 3 | bambous virieux
# Processing Record 22 of Set 3 | vila franca do campo
# Processing Record 23 of Set 3 | vigrestad
# Processing Record 24 of Set 3 | grindavik
# Processing Record 25 of Set 3 | chenzhou
# Processing Record 26 of Set 3 | ngukurr
# City not found. Skipping....
# Processing Record 27 of Set 3 | aranda de duero
# Processing Record 28 of Set 3 | santa fe
# Processing Record 29 of Set 3 | bathsheba
# Processing Record 30 of Set 3 | mulanur
# Processing Record 31 of Set 3 | saveh
# Processing Record 32 of Set 3 | guerrero negro
# Processing Record 33 of Set 3 | changji
# Processing Record 34 of Set 3 | bethel
# Processing Record 35 of Set 3 | marawi
# Processing Record 36 of Set 3 | redlands
# Processing Record 37 of Set 3 | kangaatsiaq
# Processing Record 38 of Set 3 | sioux lookout
# Processing Record 39 of Set 3 | souillac
# Processing Record 40 of Set 3 | bolungarvik
# City not found. Skipping....
# Processing Record 41 of Set 3 | havre-saint-pierre
# Processing Record 42 of Set 3 | panixtlahuaca
# City not found. Skipping....
# Processing Record 43 of Set 3 | faanui
# Processing Record 44 of Set 3 | aksarka
# Processing Record 45 of Set 3 | henties bay
# Processing Record 46 of Set 3 | katsiveli
# City not found. Skipping....
# Processing Record 47 of Set 3 | ola
# Processing Record 48 of Set 3 | pemba
# Processing Record 49 of Set 3 | doha
# Processing Record 50 of Set 3 | mount isa
# Processing Record 1 of Set 4 | hvide sande
# Processing Record 2 of Set 4 | salalah
# Processing Record 3 of Set 4 | saleaula
# City not found. Skipping....
# Processing Record 4 of Set 4 | cabo san lucas
# Processing Record 5 of Set 4 | batagay-alyta
# Processing Record 6 of Set 4 | villamontes
# Processing Record 7 of Set 4 | mehamn
# Processing Record 8 of Set 4 | fuyang
# Processing Record 9 of Set 4 | tautira
# Processing Record 10 of Set 4 | talnakh
# Processing Record 11 of Set 4 | sistranda
# Processing Record 12 of Set 4 | chapais
# Processing Record 13 of Set 4 | uyuni
# Processing Record 14 of Set 4 | cape canaveral
# Processing Record 15 of Set 4 | isla vista
# Processing Record 16 of Set 4 | umzimvubu
# City not found. Skipping....
# Processing Record 17 of Set 4 | kapoeta
# Processing Record 18 of Set 4 | panambi
# Processing Record 19 of Set 4 | lilongwe
# Processing Record 20 of Set 4 | ngunguru
# Processing Record 21 of Set 4 | dingle
# Processing Record 22 of Set 4 | carmo do paranaiba
# Processing Record 23 of Set 4 | ulaangom
# Processing Record 24 of Set 4 | hidalgo
# Processing Record 25 of Set 4 | dudinka
# Processing Record 26 of Set 4 | yulara
# Processing Record 27 of Set 4 | payette
# Processing Record 28 of Set 4 | vung tau
# Processing Record 29 of Set 4 | beringovskiy
# Processing Record 30 of Set 4 | mar del plata
# Processing Record 31 of Set 4 | tuktoyaktuk
# Processing Record 32 of Set 4 | coquimbo
# Processing Record 33 of Set 4 | itarema
# Processing Record 34 of Set 4 | kloulklubed
# Processing Record 35 of Set 4 | cheremukhovo
# Processing Record 36 of Set 4 | kearney
# Processing Record 37 of Set 4 | thinadhoo
# Processing Record 38 of Set 4 | khatanga
# Processing Record 39 of Set 4 | nikolayevsk-na-amure
# Processing Record 40 of Set 4 | illoqqortoormiut
# City not found. Skipping....
# Processing Record 41 of Set 4 | palmer
# Processing Record 42 of Set 4 | fram
# Processing Record 43 of Set 4 | avera
# Processing Record 44 of Set 4 | marcona
# City not found. Skipping....
# Processing Record 45 of Set 4 | kortkeros
# Processing Record 46 of Set 4 | lata
# Processing Record 47 of Set 4 | geraldton
# Processing Record 48 of Set 4 | victoria
# Processing Record 49 of Set 4 | ponta do sol
# Processing Record 50 of Set 4 | ouallam
# Processing Record 1 of Set 5 | saskylakh
# Processing Record 2 of Set 5 | burica
# City not found. Skipping....
# Processing Record 3 of Set 5 | gidole
# Processing Record 4 of Set 5 | gayny
# Processing Record 5 of Set 5 | amderma
# City not found. Skipping....
# Processing Record 6 of Set 5 | kinkala
# Processing Record 7 of Set 5 | ust-karsk
# Processing Record 8 of Set 5 | tamandare
# Processing Record 9 of Set 5 | kipushi
# Processing Record 10 of Set 5 | shirokiy
# Processing Record 11 of Set 5 | portknockie
# Processing Record 12 of Set 5 | panalingaan
# Processing Record 13 of Set 5 | vostok
# Processing Record 14 of Set 5 | vanimo
# Processing Record 15 of Set 5 | porbandar
# Processing Record 16 of Set 5 | harper
# Processing Record 17 of Set 5 | longyearbyen
# Processing Record 18 of Set 5 | san cristobal
# Processing Record 19 of Set 5 | sakakah
# Processing Record 20 of Set 5 | ust-tsilma
# Processing Record 21 of Set 5 | aykhal
# Processing Record 22 of Set 5 | tsihombe
# City not found. Skipping....
# Processing Record 23 of Set 5 | amazar
# Processing Record 24 of Set 5 | tiruvottiyur
# City not found. Skipping....
# Processing Record 25 of Set 5 | nicolas de pierola
# Processing Record 26 of Set 5 | vila do maio
# Processing Record 27 of Set 5 | port augusta
# Processing Record 28 of Set 5 | kovur
# Processing Record 29 of Set 5 | hami
# Processing Record 30 of Set 5 | vao
# Processing Record 31 of Set 5 | phalombe
# Processing Record 32 of Set 5 | chokurdakh
# Processing Record 33 of Set 5 | hamilton
# Processing Record 34 of Set 5 | leningradskiy
# Processing Record 35 of Set 5 | plattsburgh
# Processing Record 36 of Set 5 | beinamar
# Processing Record 37 of Set 5 | mana
# Processing Record 38 of Set 5 | fort saint john
# City not found. Skipping....
# Processing Record 39 of Set 5 | alyangula
# Processing Record 40 of Set 5 | roma
# Processing Record 41 of Set 5 | lalsk
# Processing Record 42 of Set 5 | ambilobe
# Processing Record 43 of Set 5 | zachary
# Processing Record 44 of Set 5 | rodrigues alves
# Processing Record 45 of Set 5 | elko
# Processing Record 46 of Set 5 | hasaki
# Processing Record 47 of Set 5 | barawe
# City not found. Skipping....
# Processing Record 48 of Set 5 | champerico
# Processing Record 49 of Set 5 | bereda
# Processing Record 50 of Set 5 | dien bien
# City not found. Skipping....
# Processing Record 1 of Set 6 | abu dhabi
# Processing Record 2 of Set 6 | paamiut
# Processing Record 3 of Set 6 | tezu
# Processing Record 4 of Set 6 | utiroa
# City not found. Skipping....
# Processing Record 5 of Set 6 | samarai
# Processing Record 6 of Set 6 | soure
# Processing Record 7 of Set 6 | loreto
# Processing Record 8 of Set 6 | hearst
# Processing Record 9 of Set 6 | qianan
# Processing Record 10 of Set 6 | kysyl-syr
# Processing Record 11 of Set 6 | cayenne
# Processing Record 12 of Set 6 | sao filipe
# Processing Record 13 of Set 6 | stutterheim
# Processing Record 14 of Set 6 | richards bay
# Processing Record 15 of Set 6 | alice springs
# Processing Record 16 of Set 6 | murree
# Processing Record 17 of Set 6 | erzin
# Processing Record 18 of Set 6 | opuwo
# Processing Record 19 of Set 6 | onguday
# Processing Record 20 of Set 6 | kurilsk
# Processing Record 21 of Set 6 | tyukhtet
# Processing Record 22 of Set 6 | erattupetta
# Processing Record 23 of Set 6 | morondava
# Processing Record 24 of Set 6 | whitehorse
# Processing Record 25 of Set 6 | terney
# Processing Record 26 of Set 6 | mount gambier
# Processing Record 27 of Set 6 | berdigestyakh
# Processing Record 28 of Set 6 | jinchang
# Processing Record 29 of Set 6 | yebaishou
# Processing Record 30 of Set 6 | pozorice
# Processing Record 31 of Set 6 | jieshi
# Processing Record 32 of Set 6 | borlange
# City not found. Skipping....
# Processing Record 33 of Set 6 | hobyo
# Processing Record 34 of Set 6 | tommot
# Processing Record 35 of Set 6 | yenagoa
# Processing Record 36 of Set 6 | codrington
# Processing Record 37 of Set 6 | mpika
# Processing Record 38 of Set 6 | clarence town
# Processing Record 39 of Set 6 | half moon bay
# Processing Record 40 of Set 6 | norman wells
# Processing Record 41 of Set 6 | brownfield
# Processing Record 42 of Set 6 | thompson
# Processing Record 43 of Set 6 | ostrovnoy
# Processing Record 44 of Set 6 | nuuk
# Processing Record 45 of Set 6 | lavrentiya
# Processing Record 46 of Set 6 | viedma
# Processing Record 47 of Set 6 | mrirt
# City not found. Skipping....
# Processing Record 48 of Set 6 | galesong
# Processing Record 49 of Set 6 | port blair
# Processing Record 50 of Set 6 | vestmannaeyjar
# Processing Record 1 of Set 7 | meyungs
# City not found. Skipping....
# Processing Record 2 of Set 7 | luanda
# Processing Record 3 of Set 7 | ninghai
# Processing Record 4 of Set 7 | karaton
# Processing Record 5 of Set 7 | olden
# Processing Record 6 of Set 7 | katsuura
# Processing Record 7 of Set 7 | te anau
# Processing Record 8 of Set 7 | kaeo
# Processing Record 9 of Set 7 | kansanshi
# Processing Record 10 of Set 7 | khilok
# Processing Record 11 of Set 7 | kajaani
# Processing Record 12 of Set 7 | humberto de campos
# Processing Record 13 of Set 7 | pisco
# Processing Record 14 of Set 7 | goderich
# Processing Record 15 of Set 7 | shimoda
# Processing Record 16 of Set 7 | yerbogachen
# Processing Record 17 of Set 7 | lodja
# Processing Record 18 of Set 7 | ambanja
# Processing Record 19 of Set 7 | bandarbeyla
# Processing Record 20 of Set 7 | diu
# Processing Record 21 of Set 7 | gizo
# Processing Record 22 of Set 7 | tura
# Processing Record 23 of Set 7 | redmond
# Processing Record 24 of Set 7 | rivadavia
# Processing Record 25 of Set 7 | sitka
# Processing Record 26 of Set 7 | hasanabad
# Processing Record 27 of Set 7 | mercedes
# Processing Record 28 of Set 7 | birao
# Processing Record 29 of Set 7 | rocha
# Processing Record 30 of Set 7 | merauke
# Processing Record 31 of Set 7 | ilulissat
# Processing Record 32 of Set 7 | vestmanna
# Processing Record 33 of Set 7 | lakhimpur
# Processing Record 34 of Set 7 | guangyuan
# Processing Record 35 of Set 7 | urusha
# Processing Record 36 of Set 7 | plettenberg bay
# Processing Record 37 of Set 7 | ternate
# Processing Record 38 of Set 7 | northam
# Processing Record 39 of Set 7 | manokwari
# Processing Record 40 of Set 7 | luderitz
# Processing Record 41 of Set 7 | novikovo
# Processing Record 42 of Set 7 | kudahuvadhoo
# Processing Record 43 of Set 7 | cordoba
# Processing Record 44 of Set 7 | key west
# Processing Record 45 of Set 7 | kaniama
# Processing Record 46 of Set 7 | lichinga
# Processing Record 47 of Set 7 | constitucion
# Processing Record 48 of Set 7 | simpang
# Processing Record 49 of Set 7 | prainha
# Processing Record 50 of Set 7 | aklavik
# Processing Record 1 of Set 8 | winsum
# Processing Record 2 of Set 8 | axim
# Processing Record 3 of Set 8 | nikolskoye
# Processing Record 4 of Set 8 | egvekinot
# Processing Record 5 of Set 8 | visby
# Processing Record 6 of Set 8 | chisinau
# Processing Record 7 of Set 8 | san patricio
# Processing Record 8 of Set 8 | lao cai
# Processing Record 9 of Set 8 | sentyabrskiy
# City not found. Skipping....
# Processing Record 10 of Set 8 | strezhevoy
# Processing Record 11 of Set 8 | dezful
# Processing Record 12 of Set 8 | colares
# Processing Record 13 of Set 8 | turtas
# Processing Record 14 of Set 8 | moree
# Processing Record 15 of Set 8 | alegrete
# Processing Record 16 of Set 8 | teya
# Processing Record 17 of Set 8 | havoysund
# Processing Record 18 of Set 8 | peniche
# Processing Record 19 of Set 8 | oktyabrskiy
# Processing Record 20 of Set 8 | vallenar
# Processing Record 21 of Set 8 | yarada
# Processing Record 22 of Set 8 | douentza
# Processing Record 23 of Set 8 | quatre cocos
# Processing Record 24 of Set 8 | ahipara
# Processing Record 25 of Set 8 | puerto el triunfo
# Processing Record 26 of Set 8 | dingli
# Processing Record 27 of Set 8 | asau
# Processing Record 28 of Set 8 | port hardy
# Processing Record 29 of Set 8 | macae
# Processing Record 30 of Set 8 | nouadhibou
# Processing Record 31 of Set 8 | verkhnevilyuysk
# Processing Record 32 of Set 8 | riyadh
# Processing Record 33 of Set 8 | la brea
# Processing Record 34 of Set 8 | anadyr
# Processing Record 35 of Set 8 | noumea
# Processing Record 36 of Set 8 | bondo
# Processing Record 37 of Set 8 | zolotinka
# City not found. Skipping....
# Processing Record 38 of Set 8 | baykit
# Processing Record 39 of Set 8 | hofn
# Processing Record 40 of Set 8 | vredendal
# Processing Record 41 of Set 8 | muzhi
# Processing Record 42 of Set 8 | mahibadhoo
# Processing Record 43 of Set 8 | ko samui
# Processing Record 44 of Set 8 | madera
# Processing Record 45 of Set 8 | hay river
# Processing Record 46 of Set 8 | luba
# Processing Record 47 of Set 8 | klaksvik
# Processing Record 48 of Set 8 | deputatskiy
# Processing Record 49 of Set 8 | nantucket
# Processing Record 50 of Set 8 | yeppoon
# Processing Record 1 of Set 9 | ulladulla
# Processing Record 2 of Set 9 | el retorno
# Processing Record 3 of Set 9 | pangnirtung
# Processing Record 4 of Set 9 | kargopol
# Processing Record 5 of Set 9 | kungurtug
# Processing Record 6 of Set 9 | gamba
# Processing Record 7 of Set 9 | sibu
# Processing Record 8 of Set 9 | tabou
# Processing Record 9 of Set 9 | os
# City not found. Skipping....
# Processing Record 10 of Set 9 | nguiu
# City not found. Skipping....
# Processing Record 11 of Set 9 | green river
# Processing Record 12 of Set 9 | manyana
# Processing Record 13 of Set 9 | sumbe
# Processing Record 14 of Set 9 | daru
# Processing Record 15 of Set 9 | fujieda
# Processing Record 16 of Set 9 | sohbatpur
# Processing Record 17 of Set 9 | myitkyina
# Processing Record 18 of Set 9 | faya
# Processing Record 19 of Set 9 | batetskiy
# Processing Record 20 of Set 9 | labuhan
# Processing Record 21 of Set 9 | koror
# Processing Record 22 of Set 9 | aleksandrovskoye
# Processing Record 23 of Set 9 | ostersund
# Processing Record 24 of Set 9 | lindi
# Processing Record 25 of Set 9 | lasa
# Processing Record 26 of Set 9 | diffa
# Processing Record 27 of Set 9 | marsh harbour
# Processing Record 28 of Set 9 | camacha
# Processing Record 29 of Set 9 | tatawin
# Processing Record 30 of Set 9 | kavieng
# Processing Record 31 of Set 9 | tiznit
# Processing Record 32 of Set 9 | ponta delgada
# Processing Record 33 of Set 9 | savinka
# Processing Record 34 of Set 9 | svetlyy
# Processing Record 35 of Set 9 | semporna
# Processing Record 36 of Set 9 | bristol
# Processing Record 37 of Set 9 | sibolga
# Processing Record 38 of Set 9 | pacific grove
# Processing Record 39 of Set 9 | gazojak
# Processing Record 40 of Set 9 | antigonish
# Processing Record 41 of Set 9 | semey
# Processing Record 42 of Set 9 | balikpapan
# Processing Record 43 of Set 9 | ilebo
# Processing Record 44 of Set 9 | mikkeli
# Processing Record 45 of Set 9 | basco
# Processing Record 46 of Set 9 | vila velha
# Processing Record 47 of Set 9 | laukaa
# Processing Record 48 of Set 9 | chamonix-mont-blanc
# Processing Record 49 of Set 9 | zhigansk
# Processing Record 50 of Set 9 | san quintin
# Processing Record 1 of Set 10 | kuche
# City not found. Skipping....
# Processing Record 2 of Set 10 | alzamay
# Processing Record 3 of Set 10 | sechura
# Processing Record 4 of Set 10 | resistencia
# Processing Record 5 of Set 10 | amudat
# Processing Record 6 of Set 10 | huangzhou
# Processing Record 7 of Set 10 | benjamin constant
# Processing Record 8 of Set 10 | pangody
# Processing Record 9 of Set 10 | grand gaube
# Processing Record 10 of Set 10 | inta
# Processing Record 11 of Set 10 | teavaro
# Processing Record 12 of Set 10 | ormara
# Processing Record 13 of Set 10 | ruatoria
# City not found. Skipping....
# Processing Record 14 of Set 10 | attawapiskat
# City not found. Skipping....
# Processing Record 15 of Set 10 | touros
# Processing Record 16 of Set 10 | yuxia
# Processing Record 17 of Set 10 | medicine hat
# Processing Record 18 of Set 10 | bell ville
# Processing Record 19 of Set 10 | vanavara
# Processing Record 20 of Set 10 | mogadishu
# Processing Record 21 of Set 10 | hokitika
# Processing Record 22 of Set 10 | revelstoke
# Processing Record 23 of Set 10 | liverpool
# Processing Record 24 of Set 10 | lorengau
# Processing Record 25 of Set 10 | seinajoki
# Processing Record 26 of Set 10 | charters towers
# Processing Record 27 of Set 10 | sorong
# Processing Record 28 of Set 10 | klaebu
# Processing Record 29 of Set 10 | conceicao do araguaia
# Processing Record 30 of Set 10 | kuusamo
# Processing Record 31 of Set 10 | raduzhnyy
# Processing Record 32 of Set 10 | gorontalo
# Processing Record 33 of Set 10 | zambezi
# Processing Record 34 of Set 10 | babanusah
# City not found. Skipping....
# Processing Record 35 of Set 10 | kushiro
# Processing Record 36 of Set 10 | guadalupe
# Processing Record 37 of Set 10 | penzance
# Processing Record 38 of Set 10 | kilmez
# City not found. Skipping....
# Processing Record 39 of Set 10 | tra vinh
# Processing Record 40 of Set 10 | rongcheng
# Processing Record 41 of Set 10 | eskasem
# City not found. Skipping....
# Processing Record 42 of Set 10 | zaysan
# Processing Record 43 of Set 10 | lyaskelya
# Processing Record 44 of Set 10 | hattiesburg
# Processing Record 45 of Set 10 | airai
# Processing Record 46 of Set 10 | voyvozh
# Processing Record 47 of Set 10 | roanne
# Processing Record 48 of Set 10 | antofagasta
# Processing Record 49 of Set 10 | canaries
# Processing Record 50 of Set 10 | srandakan
# Processing Record 1 of Set 11 | qui nhon
# Processing Record 2 of Set 11 | odweyne
# Processing Record 3 of Set 11 | taua
# Processing Record 4 of Set 11 | raahe
# Processing Record 5 of Set 11 | newcastle
# Processing Record 6 of Set 11 | porto walter
# Processing Record 7 of Set 11 | lompoc
# Processing Record 8 of Set 11 | igrim
# Processing Record 9 of Set 11 | katyuzhanka
# Processing Record 10 of Set 11 | chuy
# Processing Record 11 of Set 11 | jumla
# Processing Record 12 of Set 11 | ancud
# Processing Record 13 of Set 11 | shunyi
# Processing Record 14 of Set 11 | ahuimanu
# Processing Record 15 of Set 11 | tema
# Processing Record 16 of Set 11 | araguaina
# Processing Record 17 of Set 11 | oranjestad
# Processing Record 18 of Set 11 | roebourne
# Processing Record 19 of Set 11 | toliary
# City not found. Skipping....
# Processing Record 20 of Set 11 | khovu-aksy
# Processing Record 21 of Set 11 | grand river south east
# City not found. Skipping....
# Processing Record 22 of Set 11 | tunduru
# City not found. Skipping....
# Processing Record 23 of Set 11 | tuatapere
# Processing Record 24 of Set 11 | krasnoselkup
# Processing Record 25 of Set 11 | dedougou
# Processing Record 26 of Set 11 | fortuna
# Processing Record 27 of Set 11 | motril
# Processing Record 28 of Set 11 | craig
# Processing Record 29 of Set 11 | sabang
# Processing Record 30 of Set 11 | langsa
# Processing Record 31 of Set 11 | yichang
# Processing Record 32 of Set 11 | vytegra
# Processing Record 33 of Set 11 | huarmey
# Processing Record 34 of Set 11 | erenhot
# Processing Record 35 of Set 11 | iseyin
# Processing Record 36 of Set 11 | severnyy
# Processing Record 37 of Set 11 | norfolk
# Processing Record 38 of Set 11 | paso de los toros
# Processing Record 39 of Set 11 | khash
# Processing Record 40 of Set 11 | rio grande
# Processing Record 41 of Set 11 | honningsvag
# Processing Record 42 of Set 11 | pevek
# Processing Record 43 of Set 11 | give
# Processing Record 44 of Set 11 | grand centre
# City not found. Skipping....
# Processing Record 45 of Set 11 | vestbygda
# City not found. Skipping....
# Processing Record 46 of Set 11 | pemangkat
# Processing Record 47 of Set 11 | chaa-khol
# City not found. Skipping....
# Processing Record 48 of Set 11 | manta
# Processing Record 49 of Set 11 | port hedland
# Processing Record 50 of Set 11 | zapolyarnyy
# Processing Record 1 of Set 12 | omsukchan
# Processing Record 2 of Set 12 | west wendover
# Processing Record 3 of Set 12 | mayskiy
# Processing Record 4 of Set 12 | campbell river
# Processing Record 5 of Set 12 | reichenau
# Processing Record 6 of Set 12 | sumkino
# Processing Record 7 of Set 12 | soyo
# Processing Record 8 of Set 12 | mombasa
# Processing Record 9 of Set 12 | sandakan
# Processing Record 10 of Set 12 | taormina
# Processing Record 11 of Set 12 | adrar
# Processing Record 12 of Set 12 | port macquarie
# Processing Record 13 of Set 12 | arbagar
# Processing Record 14 of Set 12 | ipora
# Processing Record 15 of Set 12 | vidalia
# Processing Record 16 of Set 12 | viligili
# City not found. Skipping....
# Processing Record 17 of Set 12 | itoman
# Processing Record 18 of Set 12 | tari
# Processing Record 19 of Set 12 | cerrito
# Processing Record 20 of Set 12 | gat
# Processing Record 21 of Set 12 | quirinopolis
# Processing Record 22 of Set 12 | iquique
# Processing Record 23 of Set 12 | zeya
# Processing Record 24 of Set 12 | tres arroyos
# Processing Record 25 of Set 12 | harrisburg
# Processing Record 26 of Set 12 | praya
# Processing Record 27 of Set 12 | businga
# Processing Record 28 of Set 12 | kalmunai
# Processing Record 29 of Set 12 | russell
# Processing Record 30 of Set 12 | hudson bay
# Processing Record 31 of Set 12 | denpasar
# Processing Record 32 of Set 12 | warrnambool
# Processing Record 33 of Set 12 | gijon
# Processing Record 34 of Set 12 | borgarnes
# Processing Record 35 of Set 12 | biak
# Processing Record 36 of Set 12 | maragogi
# Processing Record 37 of Set 12 | bukachacha
# Processing Record 38 of Set 12 | misratah
# Processing Record 39 of Set 12 | bodden town
# Processing Record 40 of Set 12 | solovetskiy
# City not found. Skipping....
# Processing Record 41 of Set 12 | nau
# Processing Record 42 of Set 12 | prince rupert
# Processing Record 43 of Set 12 | nipawin
# Processing Record 44 of Set 12 | karaul
# City not found. Skipping....
# Processing Record 45 of Set 12 | green valley
# Processing Record 46 of Set 12 | matagami
# Processing Record 47 of Set 12 | agadez
# Processing Record 48 of Set 12 | lephepe
# City not found. Skipping....
# Processing Record 49 of Set 12 | sao joao da barra
# Processing Record 50 of Set 12 | swift current
# Processing Record 1 of Set 13 | maridi
# --------------------
# Data Retrieval Complete
# --------------------

# %%
len(city_data)
# Out:
# 553

# %%
# Convert list of dictionaries to pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City    Lat     Lng  Max Temp Current Description  Rain (inches)  \
# 0           vardo  70.37   31.11     44.60          few clouds            0.0
# 1          avarua -21.21 -159.78     75.20     overcast clouds            0.0
# 2        hermanus -34.42   19.23     55.00       broken clouds            0.0
# 3  saint-philippe -21.36   55.77     66.20    scattered clouds            0.0
# 4     yellowknife  62.46 -114.35     79.00          few clouds            0.0
# 5       busselton -33.65  115.33     57.00          few clouds            0.0
# 6          katobu  -4.94  122.53     74.10    scattered clouds            0.0
# 7        cherskiy  68.75  161.30     84.15          few clouds            0.0
# 8         qaanaaq  77.48  -69.36     39.47    scattered clouds            0.0
# 9            jalu  29.03   21.55     74.10           clear sky            0.0
#
#    Snow (inches)  Humidity  Cloudiness  Wind Speed Country
# 0            0.0        87          20        2.24      NO
# 1            0.0        64          98        9.17      CK
# 2            0.0        91          62        5.75      ZA
# 3            0.0        82          43        4.70      RE
# 4            0.0        38          20       19.46      CA
# 5            0.0        53          23       21.18      AU
# 6            0.0        91          48        6.51      ID
# 7            0.0        23          16       16.96      RU
# 8            0.0        72          27        3.69      GL
# 9            0.0        55           0       13.33      LY

# %%
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description',
#        'Rain (inches)', 'Snow (inches)', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country'],
#       dtype='object')

# %%
new_column_order = sorted(city_data_df.columns.tolist())
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                   City  Cloudiness Country Current Description  Humidity  \
# 0                vardo          20      NO          few clouds        87
# 1               avarua          98      CK     overcast clouds        64
# 2             hermanus          62      ZA       broken clouds        91
# 3       saint-philippe          43      RE    scattered clouds        82
# 4          yellowknife          20      CA          few clouds        38
# ..                 ...         ...     ...                 ...       ...
# 548           matagami          90      CA          light rain        65
# 549             agadez           0      NE           clear sky        11
# 550  sao joao da barra           0      BR           clear sky        78
# 551      swift current          20      CA          few clouds        59
# 552             maridi           0      SS           clear sky        93
#
#        Lat     Lng  Max Temp  Rain (inches)  Snow (inches)  Wind Speed
# 0    70.37   31.11     44.60            0.0            0.0        2.24
# 1   -21.21 -159.78     75.20            0.0            0.0        9.17
# 2   -34.42   19.23     55.00            0.0            0.0        5.75
# 3   -21.36   55.77     66.20            0.0            0.0        4.70
# 4    62.46 -114.35     79.00            0.0            0.0       19.46
# ..     ...     ...       ...            ...            ...         ...
# 548  49.75  -77.63     77.00            0.0            0.0        8.05
# 549  19.75   10.25     86.47            0.0            0.0        4.70
# 550 -21.64  -41.05     75.20            0.0            0.0       11.41
# 551  50.28 -107.80     62.60            0.0            0.0        8.05
# 552   4.92   29.47     66.36            0.0            0.0        2.55
#
# [553 rows x 11 columns]

# %%
city_data_df.dtypes
# Out:
# City                    object
# Cloudiness               int64
# Country                 object
# Current Description     object
# Humidity                 int64
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Rain (inches)          float64
# Snow (inches)          float64
# Wind Speed             float64
# dtype: object

# %%
raining_cities = city_data_df.loc[city_data_df["Rain (inches)"] > 0 ]
raining_cities.head()
# Out:
#               City  Cloudiness Country          Current Description  Humidity  \
# 13          hobart          75      AU  light intensity shower rain        93
# 19      shenjiamen         100      CN                moderate rain        99
# 25     new norfolk         100      AU                moderate rain        93
# 32  port elizabeth           4      ZA                   light rain        87
# 42     grand-santi          34      GF                   light rain        93
#
#       Lat     Lng  Max Temp  Rain (inches)  Snow (inches)  Wind Speed
# 13 -42.88  147.33     54.00           0.76           0.76        6.93
# 19  29.96  122.30     72.75           3.54           3.54        9.69
# 25 -42.78  147.06     54.00           1.52           1.52        3.53
# 32 -33.92   25.57     57.20           0.12           0.12        8.05
# 42   4.25  -54.38     75.61           0.19           0.19        3.65

# %%
snowing_cities = city_data_df.loc[city_data_df["Snow (inches)"] > 0 ]
snowing_cities.head()
# Out:
#               City  Cloudiness Country          Current Description  Humidity  \
# 13          hobart          75      AU  light intensity shower rain        93
# 19      shenjiamen         100      CN                moderate rain        99
# 25     new norfolk         100      AU                moderate rain        93
# 32  port elizabeth           4      ZA                   light rain        87
# 42     grand-santi          34      GF                   light rain        93
#
#       Lat     Lng  Max Temp  Rain (inches)  Snow (inches)  Wind Speed
# 13 -42.88  147.33     54.00           0.76           0.76        6.93
# 19  29.96  122.30     72.75           3.54           3.54        9.69
# 25 -42.78  147.06     54.00           1.52           1.52        3.53
# 32 -33.92   25.57     57.20           0.12           0.12        8.05
# 42   4.25  -54.38     75.61           0.19           0.19        3.65

# %%
# Create the output file (CSV)
output_data_file = "data/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
